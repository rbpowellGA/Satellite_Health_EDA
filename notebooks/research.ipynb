# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('../data/sat_health/satellite_health_dataset.csv')

# %%
df.head(10)
# Out:
#    time_since_launch  orbital_altitude  battery_voltage  \
# 0               3174       1827.203968        28.633451
# 1               3507       1290.566449        21.591647
# 2                860        510.982525        20.150880
# 3               1294        506.405339              NaN
# 4               1130       1525.925008        24.321029
# 5               1095        612.433931        25.519012
# 6               3092        858.255349        28.332218
# 7               1638       1128.260412        28.023606
# 8               2169        342.100292        21.000433
# 9                466        722.992346        29.339954
#
#    solar_panel_temperature  attitude_control_error  data_transmission_rate  \
# 0               -13.074553                1.553314               10.600079
# 1               -15.568622                2.593412               47.291054
# 2                28.709230                2.680357               33.734476
# ...

# %%
df.corr()
# Out:
#                          time_since_launch  orbital_altitude  battery_voltage  \
# time_since_launch                 1.000000          0.005489        -0.003214
# orbital_altitude                  0.005489          1.000000         0.006205
# battery_voltage                  -0.003214          0.006205         1.000000
# solar_panel_temperature          -0.003672         -0.002839        -0.005340
# attitude_control_error           -0.012640         -0.002883         0.000014
# data_transmission_rate            0.030948         -0.001574        -0.011174
# thermal_control_status            0.016281          0.002851         0.001559
# satellite_health                 -0.001537         -0.002544         0.010264
#
#                          solar_panel_temperature  attitude_control_error  \
# time_since_launch                      -0.003672               -0.012640
# orbital_altitude                       -0.002839               -0.002883
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >
